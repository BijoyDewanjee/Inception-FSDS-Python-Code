# %% [markdown]
# #Assignment 1: Temperature Check
# ## Problem:
# ##Write a program that takes the current temperature as input and prints:
# ### ● "It's too cold!" if below 10°C
# ### ● "It's cool outside" if between 10°C and 25°C.
# ### ● "It's hot outside!" if above 25°C

# %%
temp=int(input("Enter Your  Temperature :"))
if temp<10:
  print("It's too cold!")
elif temp>=10 and temp<=25:
  print( "It's cool outside" )
else:
  print("It's hot outside!")
# Out:
# Enter Your  Temperature :12
# It's cool outside

# %% [markdown]
# # **Assignment 2: ATM Withdrawal System**
# ## Problem:
# ## Ask the user for their account balance and the amount they want to withdraw.
# ### ● If the withdrawal amount is greater than the balance → print "Insufficient Balance"
# ### ● If the withdrawal amount is less than or equal to balance → print "Transaction Successful" and show the remaining balance.

# %%
Balance=float(input("Enter your Balance:"))
Withdraw=float(input("Enter Your Withdraw Amount:"))
Remain_Balance=Balance-Withdraw
if(Withdraw<=Balance):
  print("Transaction Successful and Remaining Balance",Remain_Balance)
else:
  print("Insufficient Balance")
# Out:
# Transaction Successful and Remaining Balance 2000.0

# %% [markdown]
# # **Assignment 3: Student Grade Calculator**
# ## **Problem:**
# ## Input marks (0–100) and print grade based on:
# ## ● 90–100 → A+
# ## ● 80–89 → A
# ## ● 70–79 → B
# ## ● 60–69 → C
# ## ● Below 60 → Fail

# %%
marks=int(input("Enter Your Marks:"))
if(marks>=90 and marks<=100):
  print("A+")
elif(marks>=80 and marks<=89):
  print("A")
elif(marks>=70 and marks<=79):
  print("B")
elif(marks>=60 and marks<=69):
  print("C")
else:
  print("Fail")
# Out:
# Enter Your Marks:99
# A+

# %% [markdown]
# # **Assignment 4: Bus Ticket Discount**
# ## Problem:
# ## Ask the user for age and print ticket price:
# ### ● Below 5 → Free
# ### ● 5–18 → 50% Discount
# ### ● 60 or above → 30% Discount
# ### ● Others → Full Price

# %%
Age=int(input("Enter your Age :"))
price=int(input("Enter Tricket Price: "))
afer_Discounted_Price=0
if(Age<5):
  print("Ticekt Price Free=",afer_Discounted_Price)
elif(Age>=5 and Age<=18):
  afer_Discounted_Price=price*0.50
  print("50% Discounted After tricket price = ",afer_Discounted_Price )
elif(Age>=60):
      afer_Discounted_Price =price*0.70
      print("30% Deiscounted After tricket price ",afer_Discounted_Price )

else:
  afer_Discounted_Price=price
  print("Full Price =",afer_Discounted_Price)
# Out:
# Enter your Age :34
# Enter Tricket Price: 100
# Full Price = 100

# %% [markdown]
# # **Assignment 5: Restaurant Bill with Discount**
# ## Problem:
# ## Take total bill amount from the user:
# ## ● If the bill is above 1000 → apply 10% discount
# ## ● Otherwise → no discount
# ## Then print the final bill amount.

# %%
bill=float(input('Enter the total bill '))
final_bill=0
if bill>1000:
  final_bill=bill*0.90
else:
  final_bill=bill
print("Final bill amount = ",final_bill)
# Out:
# Enter the total bill 2000
# Final bill amount =  1800.0

# %% [markdown]
# # **Assignment 6: Login Authentication**
# ## Problem:
# ## Take a username and password input.
# ## ● If username == "admin" and password == "12345" → print "Login Successful"
# ## ● Else → print "Invalid Credentials"

# %%
username= input("EEnter your Username :")
password=input("Enter Your Password :")
if username == "admin" and password == "12345" :
  print("Login Successful")
else:
  print('Invalid Credentials' )
# Out:
# EEnter your Username :bijoy
# Enter Your Password :23456
# Invalid Credentials

# %% [markdown]
# # **Assignment 7: Traffic Light System**
# ## Problem:
# ## Ask the user to input a color (red, yellow, or green).
# ## Print:
# ## ● "Stop" for red
# ## ● "Ready to go" for yellow
# ## ● "Go" for green
# ## ● "Invalid color" otherwise

# %%
color=input("Take a color :")
if(color=='red'):
  print("Stop")
elif(color=='yellow'):
  print("Ready to Go")
elif(color=='green'):
  print("Go")
else:
  print("Invalid Color")
# Out:
# Take a color :pink
# Invalid Color

# %% [markdown]
# # **Assignment 8: Leap Year Checker**
# ## Problem:
# ## Take a year as input and check:
# ## ● If it is divisible by 400 → Leap Year
# ## ● Else if divisible by 4 but not by 100 → Leap Year
# ## ● Otherwise → Not a Leap Year

# %%
year=float(input("Enter an year : "))
if(year%400==0):
  print("Leap Year")
elif(year%4==0 and year%100!=0):
  print("Leap year")
else:
  print("Not a Leap Year")
# Out:
# Enter an year : 1962
# Not a Leap Year

# %% [markdown]
# # **Assignment 9: Job Eligibility Checker**
# ## Problem:
# ## Input age and qualification.
# ## ● If age ≥ 18 and qualification is “graduate” → print "Eligible for Job"
# ## ● Else → "Not Eligible"

# %%
age=int(input('Enter your Age :'))
qualifications=input("Enter  your qualifications :")
if(age>= 18 and qualifications =="graduate"):
  print("Eligible for Job")
else:
  print("Not Eligible")
# Out:
# Enter your Age :35
# Enter  your qualifications :graduate
# Eligible for Job

# %% [markdown]
# # **Assignment 10: Electricity Bill Calculator**
# ## Problem:
# ## Input number of units consumed and calculate bill:
# ## ● Up to 100 units → 5 BDT per unit
# ## ● 101–200 units → 7 BDT per unit
# ## ● Above 200 units → 10 BDT per unit
# ## Print total payable amount.

# %%
unit=int(input("Enter your Unit :"))
bill=0
if(unit>0 and unit<=100):
  bill=unit*5
elif(unit>=101 and unit<=200):
  bill=unit*7
else:
  bill=unit*10
print("Total payable amount : ",bill)
# Out:
# Enter your Unit :170
# Total payable amount :  1190
